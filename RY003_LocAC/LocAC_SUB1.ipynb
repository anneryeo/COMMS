# %%
# %pip install Flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install FastAPI
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 53.0 MB/s eta 0:00:00
# ...

# %%
# %pip install NLTK
# Out:
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install SpaCY
# Out:
# ...
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    ---------------------------------------- 11.8/11.8 MB 81.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/632.6 kB ? eta -:--:--
#    ---------------------------------------- 632.6/632.6 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 92.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------  12.6/12.6 MB 60.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 56.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------------------------- -------- 5.0/6.3 MB 25.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 22.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/5.4 MB ? eta -:--:--
# ...

# %%
# %pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/643.9 kB ? eta -:--:--
#    ---------------------------------------- 643.9/643.9 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install deepseek
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gradio
# Out:
# ...
#    ---------------------------------------- 0.0/46.9 MB ? eta -:--:--
#    ------------------ --------------------- 21.5/46.9 MB 112.9 MB/s eta 0:00:01
#    --------------------- ------------------ 25.4/46.9 MB 64.4 MB/s eta 0:00:01
#    ------------------------- -------------- 29.4/46.9 MB 49.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 33.0/46.9 MB 41.1 MB/s eta 0:00:01
#    ------------------------------- -------- 37.0/46.9 MB 36.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 40.9/46.9 MB 33.3 MB/s eta 0:00:01
#    -------------------------------------- - 44.8/46.9 MB 31.3 MB/s eta 0:00:01
#    ---------------------------------------- 46.9/46.9 MB 29.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    ---------------------- ----------------- 6.6/11.4 MB 33.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.4 MB 26.2 MB/s eta 0:00:01
# ...
